# %%
# !pip install polygon-api-client
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
from polygon import RESTClient

# %%
client = RESTClient(api_key="KwXqa4Sc3xlx_0p2pfoEZlcl4rJ41dgd")

# %%
ticker = "AAPL"

# List Aggregates (Bars)
bars = client.get_aggs(ticker=ticker, multiplier=1, timespan="minute", from_="2023-01-09", to="2023-01-10")
for bar in bars:
    print(bar)
# Out:
# Agg(open=129.6, high=130.3, low=129.6, close=129.89, volume=2312, vwap=129.8763, timestamp=1673254800000, transactions=85, otc=None)
# Agg(open=129.8, high=129.8, low=129.68, close=129.7, volume=6206, vwap=129.7086, timestamp=1673254860000, transactions=74, otc=None)
# Agg(open=129.84, high=130, low=129.8, close=130, volume=2386, vwap=129.8947, timestamp=1673254920000, transactions=83, otc=None)
# Agg(open=130, high=130.01, low=129.99, close=129.99, volume=3372, vwap=130.007, timestamp=1673254980000, transactions=81, otc=None)
# Agg(open=129.98, high=129.99, low=129.98, close=129.99, volume=1087, vwap=130.0019, timestamp=1673255040000, transactions=41, otc=None)
# Agg(open=130.08, high=130.14, low=130.06, close=130.14, volume=3582, vwap=130.0971, timestamp=1673255100000, transactions=58, otc=None)
# Agg(open=130.15, high=130.17, low=130.05, close=130.05, volume=4540, vwap=130.1249, timestamp=1673255160000, transactions=90, otc=None)
# ...
